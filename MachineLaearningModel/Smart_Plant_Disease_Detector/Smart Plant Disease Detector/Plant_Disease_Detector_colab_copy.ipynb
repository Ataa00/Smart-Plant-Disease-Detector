# %%
from zipfile import ZipFile
file_name = '/content/PlantVillage2.zip'

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
from collections import OrderedDict
import matplotlib.pyplot as plt
import numpy as np
import time

from PIL import Image

import torch
from torch import nn
from torch import optim
from torchvision import datasets, transforms, models

# %% [markdown]
# ## Load the data
#
# Here I'll use `torchvision` to load the data.
#
# The pre-trained networks I'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets I'll normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = '/content/PlantVillage2'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/val'
test_dir = data_dir + '/test'

# %% [markdown]
# ### Data augmentation and normalization

# %%
# DONE: Define your transforms for the training, validation, and testing sets
training_transforms = transforms.Compose([transforms.RandomRotation(30), transforms.RandomResizedCrop(
    224), transforms.RandomHorizontalFlip(), transforms.ToTensor(), transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])
validation_transforms = transforms.Compose([transforms.Resize(255), transforms.CenterCrop(
    224), transforms.ToTensor(), transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])
testing_transforms = validation_transforms

# %% [markdown]
# ### Data Loading

# %%
# DONE: Load the datasets with ImageFolder
training_dataset = datasets.ImageFolder(
    train_dir, transform=training_transforms)
validation_dataset = datasets.ImageFolder(
    valid_dir, transform=validation_transforms)
testing_dataset = datasets.ImageFolder(test_dir, transform=testing_transforms)

# %% [markdown]
# ### Data batching

# %%
# DONE: Using the image datasets and the trainforms, define the dataloaders
training_loader = torch.utils.data.DataLoader(
    training_dataset, batch_size=64, shuffle=True)
validation_loader = torch.utils.data.DataLoader(
    validation_dataset, batch_size=64, shuffle=True)
testing_loader = torch.utils.data.DataLoader(
    testing_dataset, batch_size=64, shuffle=True)

# %% [markdown]
# ### Preparing the pre-trained network - densenet121
#
# I picked `densenet121` for this project because it can smoothly run on my local machine and it can produce great results.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %%
lr = 0.001
epochs = 5

# %%
model = models.densenet121(weights=models.DenseNet121_Weights.DEFAULT)

# Freezing the parameteres
for param in model.parameters():
    param.requires_grad = False

# Default:
# (classifier): Linear(in_features=1024, out_features=1000, bias=True)

classifier = nn.Sequential(OrderedDict([
    ('fc1', nn.Linear(1024, 512)),
    ('relu1', nn.ReLU()),
    ('dropout1', nn.Dropout(p=0.3)),
    ('fc2', nn.Linear(512, 256)),
    ('relu2', nn.ReLU()),
    ('dropout2', nn.Dropout(p=0.3)),
    ('fc3', nn.Linear(256, len(training_dataset.class_to_idx))),
    ('output', nn.LogSoftmax(dim=1))
]))

model.classifier = classifier
# Out:
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 66.5MB/s]

# %%
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=lr)

# %%
model.to(device)

steps = 0
print_every = 40

for epoch in range(epochs):
    running_loss = 0
    steps_no = len(training_loader)
    for step, (inputs, labels) in enumerate(training_loader):
        start_time = time.time()
        print(f'Step {step} of {steps_no}')
        images, labels = inputs.to(device), labels.to(
            device)  # Moving to GPU or CPU

        optimizer.zero_grad()  # Clearing the gradients

        log_ps = model.forward(images)
        loss = criterion(log_ps, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # Run validation and testing then print the results

        if steps % print_every == 0:
            validation_loss = 0
            validation_accuracy = 0



            model.eval()
            with torch.no_grad():
                for images, labels in validation_loader:

                    images, labels = images.to(device), labels.to(
                        device)  # Moving to GPU or CPU

                    log_ps = model.forward(images)
                    loss = criterion(log_ps, labels)
                    validation_loss += loss.item()

                    ps = torch.exp(log_ps)
                    top_ps, top_class = ps.topk(1, dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    validation_accuracy += torch.mean(
                        equals.type(torch.FloatTensor)).item()
            end_time = time.time()
            print(f"Epoch {epoch+1}/{epochs}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Validation loss: {validation_loss/len(validation_loader):.3f}.. "
                  f"Validation accuracy: {validation_accuracy/len(validation_loader)*100:.3f}%"
                  f"  ---  Time taken {end_time - start_time}"
                  )

            running_loss = 0

            model.train()
# Out:
# Step 0 of 170
# Epoch 1/5.. Train loss: 0.021.. Validation loss: 0.671.. Validation accuracy: 76.690%  ---  Time taken 18.560829877853394
# Step 1 of 170
# Epoch 1/5.. Train loss: 0.026.. Validation loss: 0.581.. Validation accuracy: 80.963%  ---  Time taken 17.996445178985596
# Step 2 of 170
# Epoch 1/5.. Train loss: 0.021.. Validation loss: 0.534.. Validation accuracy: 83.546%  ---  Time taken 18.480886936187744
# Step 3 of 170
# Epoch 1/5.. Train loss: 0.023.. Validation loss: 0.562.. Validation accuracy: 81.314%  ---  Time taken 18.023204565048218
# Step 4 of 170
# Epoch 1/5.. Train loss: 0.022.. Validation loss: 0.614.. Validation accuracy: 78.444%  ---  Time taken 18.451380729675293
# Step 5 of 170
# Epoch 1/5.. Train loss: 0.028.. Validation loss: 0.647.. Validation accuracy: 76.467%  ---  Time taken 17.984909296035767
# Step 6 of 170
# Epoch 1/5.. Train loss: 0.022.. Validation loss: 0.660.. Validation accuracy: 76.531%  ---  Time taken 18.45892834663391
# Step 7 of 170
# Epoch 1/5.. Train loss: 0.024.. Validation loss: 0.675.. Validation accuracy: 76.339%  ---  Time taken 18.04825758934021
# Step 8 of 170
# Epoch 1/5.. Train loss: 0.021.. Validation loss: 0.633.. Validation accuracy: 78.061%  ---  Time taken 18.396071434020996
# Step 9 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.587.. Validation accuracy: 80.995%  ---  Time taken 17.991503953933716
# Step 10 of 170
# Epoch 1/5.. Train loss: 0.022.. Validation loss: 0.559.. Validation accuracy: 82.685%  ---  Time taken 18.544116973876953
# Step 11 of 170
# Epoch 1/5.. Train loss: 0.020.. Validation loss: 0.551.. Validation accuracy: 82.940%  ---  Time taken 18.020532846450806
# Step 12 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.605.. Validation accuracy: 80.804%  ---  Time taken 18.35128092765808
# Step 13 of 170
# Epoch 1/5.. Train loss: 0.022.. Validation loss: 0.681.. Validation accuracy: 77.742%  ---  Time taken 18.07869052886963
# Step 14 of 170
# Epoch 1/5.. Train loss: 0.033.. Validation loss: 0.624.. Validation accuracy: 79.974%  ---  Time taken 18.337095975875854
# Step 15 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.561.. Validation accuracy: 81.441%  ---  Time taken 18.1093168258667
# Step 16 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.512.. Validation accuracy: 83.610%  ---  Time taken 18.2790424823761
# Step 17 of 170
# Epoch 1/5.. Train loss: 0.022.. Validation loss: 0.502.. Validation accuracy: 84.088%  ---  Time taken 18.13411021232605
# Step 18 of 170
# Epoch 1/5.. Train loss: 0.023.. Validation loss: 0.499.. Validation accuracy: 83.801%  ---  Time taken 18.21003818511963
# Step 19 of 170
# Epoch 1/5.. Train loss: 0.024.. Validation loss: 0.499.. Validation accuracy: 83.578%  ---  Time taken 18.19042158126831
# Step 20 of 170
# Epoch 1/5.. Train loss: 0.022.. Validation loss: 0.495.. Validation accuracy: 83.960%  ---  Time taken 18.28969693183899
# Step 21 of 170
# Epoch 1/5.. Train loss: 0.023.. Validation loss: 0.525.. Validation accuracy: 82.781%  ---  Time taken 18.21988320350647
# Step 22 of 170
# Epoch 1/5.. Train loss: 0.023.. Validation loss: 0.561.. Validation accuracy: 81.473%  ---  Time taken 18.147337436676025
# Step 23 of 170
# Epoch 1/5.. Train loss: 0.023.. Validation loss: 0.562.. Validation accuracy: 81.122%  ---  Time taken 18.351908922195435
# Step 24 of 170
# Epoch 1/5.. Train loss: 0.024.. Validation loss: 0.552.. Validation accuracy: 81.983%  ---  Time taken 18.014540910720825
# Step 25 of 170
# Epoch 1/5.. Train loss: 0.019.. Validation loss: 0.559.. Validation accuracy: 81.728%  ---  Time taken 18.241826057434082
# Step 26 of 170
# Epoch 1/5.. Train loss: 0.021.. Validation loss: 0.571.. Validation accuracy: 81.537%  ---  Time taken 18.07280683517456
# Step 27 of 170
# Epoch 1/5.. Train loss: 0.023.. Validation loss: 0.573.. Validation accuracy: 81.792%  ---  Time taken 18.284213066101074
# Step 28 of 170
# Epoch 1/5.. Train loss: 0.022.. Validation loss: 0.539.. Validation accuracy: 82.876%  ---  Time taken 17.93298625946045
# Step 29 of 170
# Epoch 1/5.. Train loss: 0.020.. Validation loss: 0.476.. Validation accuracy: 85.045%  ---  Time taken 18.353803396224976
# Step 30 of 170
# Epoch 1/5.. Train loss: 0.023.. Validation loss: 0.463.. Validation accuracy: 85.969%  ---  Time taken 18.056864500045776
# Step 31 of 170
# Epoch 1/5.. Train loss: 0.015.. Validation loss: 0.486.. Validation accuracy: 84.821%  ---  Time taken 18.39456534385681
# Step 32 of 170
# Epoch 1/5.. Train loss: 0.024.. Validation loss: 0.506.. Validation accuracy: 84.247%  ---  Time taken 17.986751317977905
# Step 33 of 170
# Epoch 1/5.. Train loss: 0.020.. Validation loss: 0.510.. Validation accuracy: 83.355%  ---  Time taken 18.489793062210083
# Step 34 of 170
# Epoch 1/5.. Train loss: 0.022.. Validation loss: 0.500.. Validation accuracy: 84.216%  ---  Time taken 17.978657960891724
# Step 35 of 170
# Epoch 1/5.. Train loss: 0.033.. Validation loss: 0.450.. Validation accuracy: 86.448%  ---  Time taken 18.458354949951172
# Step 36 of 170
# Epoch 1/5.. Train loss: 0.022.. Validation loss: 0.479.. Validation accuracy: 84.566%  ---  Time taken 18.014100313186646
# Step 37 of 170
# Epoch 1/5.. Train loss: 0.023.. Validation loss: 0.527.. Validation accuracy: 82.812%  ---  Time taken 18.434383153915405
# Step 38 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.541.. Validation accuracy: 82.430%  ---  Time taken 18.00139284133911
# Step 39 of 170
# Epoch 1/5.. Train loss: 0.029.. Validation loss: 0.538.. Validation accuracy: 82.462%  ---  Time taken 18.403210163116455
# Step 40 of 170
# Epoch 1/5.. Train loss: 0.021.. Validation loss: 0.525.. Validation accuracy: 82.462%  ---  Time taken 17.96101427078247
# Step 41 of 170
# Epoch 1/5.. Train loss: 0.016.. Validation loss: 0.516.. Validation accuracy: 82.717%  ---  Time taken 18.399982690811157
# Step 42 of 170
# Epoch 1/5.. Train loss: 0.017.. Validation loss: 0.497.. Validation accuracy: 83.960%  ---  Time taken 17.881053924560547
# Step 43 of 170
# Epoch 1/5.. Train loss: 0.015.. Validation loss: 0.475.. Validation accuracy: 84.598%  ---  Time taken 18.43434166908264
# Step 44 of 170
# Epoch 1/5.. Train loss: 0.020.. Validation loss: 0.471.. Validation accuracy: 84.981%  ---  Time taken 17.887444019317627
# Step 45 of 170
# Epoch 1/5.. Train loss: 0.019.. Validation loss: 0.483.. Validation accuracy: 84.630%  ---  Time taken 18.373238801956177
# Step 46 of 170
# Epoch 1/5.. Train loss: 0.016.. Validation loss: 0.497.. Validation accuracy: 83.865%  ---  Time taken 18.02206063270569
# Step 47 of 170
# Epoch 1/5.. Train loss: 0.017.. Validation loss: 0.530.. Validation accuracy: 81.856%  ---  Time taken 18.370662212371826
# Step 48 of 170
# Epoch 1/5.. Train loss: 0.020.. Validation loss: 0.559.. Validation accuracy: 80.899%  ---  Time taken 17.957958936691284
# Step 49 of 170
# Epoch 1/5.. Train loss: 0.019.. Validation loss: 0.523.. Validation accuracy: 82.207%  ---  Time taken 18.384499073028564
# Step 50 of 170
# Epoch 1/5.. Train loss: 0.022.. Validation loss: 0.485.. Validation accuracy: 84.566%  ---  Time taken 18.054966926574707
# Step 51 of 170
# Epoch 1/5.. Train loss: 0.023.. Validation loss: 0.432.. Validation accuracy: 87.213%  ---  Time taken 18.42188024520874
# Step 52 of 170
# Epoch 1/5.. Train loss: 0.014.. Validation loss: 0.406.. Validation accuracy: 88.074%  ---  Time taken 17.95361065864563
# Step 53 of 170
# Epoch 1/5.. Train loss: 0.010.. Validation loss: 0.426.. Validation accuracy: 86.352%  ---  Time taken 18.43915843963623
# Step 54 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.468.. Validation accuracy: 84.343%  ---  Time taken 17.895254850387573
# Step 55 of 170
# Epoch 1/5.. Train loss: 0.020.. Validation loss: 0.511.. Validation accuracy: 83.004%  ---  Time taken 18.426419258117676
# Step 56 of 170
# Epoch 1/5.. Train loss: 0.019.. Validation loss: 0.485.. Validation accuracy: 83.482%  ---  Time taken 18.016316413879395
# Step 57 of 170
# Epoch 1/5.. Train loss: 0.021.. Validation loss: 0.451.. Validation accuracy: 85.268%  ---  Time taken 18.4560604095459
# Step 58 of 170
# Epoch 1/5.. Train loss: 0.020.. Validation loss: 0.445.. Validation accuracy: 85.555%  ---  Time taken 17.964648008346558
# Step 59 of 170
# Epoch 1/5.. Train loss: 0.019.. Validation loss: 0.466.. Validation accuracy: 84.598%  ---  Time taken 18.359654426574707
# Step 60 of 170
# Epoch 1/5.. Train loss: 0.015.. Validation loss: 0.478.. Validation accuracy: 83.897%  ---  Time taken 17.965782642364502
# Step 61 of 170
# Epoch 1/5.. Train loss: 0.013.. Validation loss: 0.474.. Validation accuracy: 84.662%  ---  Time taken 18.487382173538208
# Step 62 of 170
# Epoch 1/5.. Train loss: 0.022.. Validation loss: 0.451.. Validation accuracy: 85.651%  ---  Time taken 17.99935007095337
# Step 63 of 170
# Epoch 1/5.. Train loss: 0.017.. Validation loss: 0.426.. Validation accuracy: 87.245%  ---  Time taken 18.357222080230713
# Step 64 of 170
# Epoch 1/5.. Train loss: 0.021.. Validation loss: 0.420.. Validation accuracy: 88.074%  ---  Time taken 18.197054624557495
# Step 65 of 170
# Epoch 1/5.. Train loss: 0.019.. Validation loss: 0.419.. Validation accuracy: 87.404%  ---  Time taken 19.00398015975952
# Step 66 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.418.. Validation accuracy: 87.277%  ---  Time taken 18.484364986419678
# Step 67 of 170
# Epoch 1/5.. Train loss: 0.015.. Validation loss: 0.410.. Validation accuracy: 86.926%  ---  Time taken 18.506852865219116
# Step 68 of 170
# Epoch 1/5.. Train loss: 0.019.. Validation loss: 0.431.. Validation accuracy: 85.236%  ---  Time taken 18.25373387336731
# Step 69 of 170
# Epoch 1/5.. Train loss: 0.016.. Validation loss: 0.459.. Validation accuracy: 84.152%  ---  Time taken 18.639490365982056
# Step 70 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.480.. Validation accuracy: 83.068%  ---  Time taken 18.059109926223755
# Step 71 of 170
# Epoch 1/5.. Train loss: 0.017.. Validation loss: 0.510.. Validation accuracy: 82.621%  ---  Time taken 18.436822652816772
# Step 72 of 170
# Epoch 1/5.. Train loss: 0.023.. Validation loss: 0.503.. Validation accuracy: 82.908%  ---  Time taken 18.46429705619812
# Step 73 of 170
# Epoch 1/5.. Train loss: 0.019.. Validation loss: 0.469.. Validation accuracy: 83.929%  ---  Time taken 18.332847595214844
# Step 74 of 170
# Epoch 1/5.. Train loss: 0.020.. Validation loss: 0.455.. Validation accuracy: 85.236%  ---  Time taken 18.369194984436035
# Step 75 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.437.. Validation accuracy: 85.714%  ---  Time taken 18.35710835456848
# Step 76 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.449.. Validation accuracy: 85.619%  ---  Time taken 18.367703199386597
# Step 77 of 170
# Epoch 1/5.. Train loss: 0.015.. Validation loss: 0.477.. Validation accuracy: 84.152%  ---  Time taken 18.200756788253784
# Step 78 of 170
# Epoch 1/5.. Train loss: 0.016.. Validation loss: 0.503.. Validation accuracy: 83.259%  ---  Time taken 18.40085768699646
# Step 79 of 170
# Epoch 1/5.. Train loss: 0.020.. Validation loss: 0.476.. Validation accuracy: 83.737%  ---  Time taken 18.049094200134277
# Step 80 of 170
# Epoch 1/5.. Train loss: 0.025.. Validation loss: 0.443.. Validation accuracy: 84.439%  ---  Time taken 18.389878034591675
# Step 81 of 170
# Epoch 1/5.. Train loss: 0.017.. Validation loss: 0.437.. Validation accuracy: 84.662%  ---  Time taken 18.125776529312134
# Step 82 of 170
# Epoch 1/5.. Train loss: 0.024.. Validation loss: 0.448.. Validation accuracy: 84.247%  ---  Time taken 18.580201148986816
# Step 83 of 170
# Epoch 1/5.. Train loss: 0.020.. Validation loss: 0.476.. Validation accuracy: 83.355%  ---  Time taken 18.071228742599487
# Step 84 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.511.. Validation accuracy: 82.015%  ---  Time taken 18.551297903060913
# Step 85 of 170
# Epoch 1/5.. Train loss: 0.019.. Validation loss: 0.535.. Validation accuracy: 81.633%  ---  Time taken 18.01279854774475
# Step 86 of 170
# Epoch 1/5.. Train loss: 0.019.. Validation loss: 0.517.. Validation accuracy: 82.781%  ---  Time taken 18.5210120677948
# Step 87 of 170
# Epoch 1/5.. Train loss: 0.023.. Validation loss: 0.484.. Validation accuracy: 84.694%  ---  Time taken 18.07650375366211
# Step 88 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.476.. Validation accuracy: 84.216%  ---  Time taken 18.795241832733154
# Step 89 of 170
# Epoch 1/5.. Train loss: 0.020.. Validation loss: 0.516.. Validation accuracy: 82.844%  ---  Time taken 18.388538360595703
# Step 90 of 170
# Epoch 1/5.. Train loss: 0.024.. Validation loss: 0.535.. Validation accuracy: 82.302%  ---  Time taken 18.6254141330719
# Step 91 of 170
# Epoch 1/5.. Train loss: 0.019.. Validation loss: 0.554.. Validation accuracy: 80.644%  ---  Time taken 18.272666692733765
# Step 92 of 170
# Epoch 1/5.. Train loss: 0.019.. Validation loss: 0.547.. Validation accuracy: 80.485%  ---  Time taken 18.842686653137207
# Step 93 of 170
# Epoch 1/5.. Train loss: 0.028.. Validation loss: 0.509.. Validation accuracy: 81.983%  ---  Time taken 18.350181818008423
# Step 94 of 170
# Epoch 1/5.. Train loss: 0.023.. Validation loss: 0.466.. Validation accuracy: 84.184%  ---  Time taken 18.811859607696533
# Step 95 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.429.. Validation accuracy: 86.703%  ---  Time taken 18.12209415435791
# Step 96 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.407.. Validation accuracy: 88.042%  ---  Time taken 18.689585208892822
# Step 97 of 170
# Epoch 1/5.. Train loss: 0.020.. Validation loss: 0.410.. Validation accuracy: 87.691%  ---  Time taken 18.576679468154907
# Step 98 of 170
# Epoch 1/5.. Train loss: 0.017.. Validation loss: 0.442.. Validation accuracy: 86.129%  ---  Time taken 18.54075527191162
# Step 99 of 170
# Epoch 1/5.. Train loss: 0.015.. Validation loss: 0.493.. Validation accuracy: 83.992%  ---  Time taken 18.435935020446777
# Step 100 of 170
# Epoch 1/5.. Train loss: 0.028.. Validation loss: 0.498.. Validation accuracy: 83.865%  ---  Time taken 18.27390193939209
# Step 101 of 170
# Epoch 1/5.. Train loss: 0.021.. Validation loss: 0.499.. Validation accuracy: 83.929%  ---  Time taken 18.55739712715149
# Step 102 of 170
# Epoch 1/5.. Train loss: 0.022.. Validation loss: 0.474.. Validation accuracy: 85.013%  ---  Time taken 18.27975058555603
# Step 103 of 170
# Epoch 1/5.. Train loss: 0.022.. Validation loss: 0.467.. Validation accuracy: 84.503%  ---  Time taken 18.768553733825684
# Step 104 of 170
# Epoch 1/5.. Train loss: 0.021.. Validation loss: 0.456.. Validation accuracy: 85.587%  ---  Time taken 18.498512744903564
# Step 105 of 170
# Epoch 1/5.. Train loss: 0.014.. Validation loss: 0.461.. Validation accuracy: 84.694%  ---  Time taken 19.048771381378174
# Step 106 of 170
# Epoch 1/5.. Train loss: 0.019.. Validation loss: 0.449.. Validation accuracy: 85.427%  ---  Time taken 18.45471715927124
# Step 107 of 170
# Epoch 1/5.. Train loss: 0.023.. Validation loss: 0.425.. Validation accuracy: 86.448%  ---  Time taken 18.71434497833252
# Step 108 of 170
# Epoch 1/5.. Train loss: 0.016.. Validation loss: 0.412.. Validation accuracy: 87.436%  ---  Time taken 18.182416200637817
# Step 109 of 170
# Epoch 1/5.. Train loss: 0.016.. Validation loss: 0.409.. Validation accuracy: 87.723%  ---  Time taken 18.725576877593994
# Step 110 of 170
# Epoch 1/5.. Train loss: 0.014.. Validation loss: 0.421.. Validation accuracy: 86.862%  ---  Time taken 18.166643142700195
# Step 111 of 170
# Epoch 1/5.. Train loss: 0.014.. Validation loss: 0.438.. Validation accuracy: 86.448%  ---  Time taken 18.564018487930298
# Step 112 of 170
# Epoch 1/5.. Train loss: 0.016.. Validation loss: 0.437.. Validation accuracy: 86.543%  ---  Time taken 18.11224603652954
# Step 113 of 170
# Epoch 1/5.. Train loss: 0.024.. Validation loss: 0.425.. Validation accuracy: 86.958%  ---  Time taken 18.5410897731781
# Step 114 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.415.. Validation accuracy: 86.798%  ---  Time taken 18.091935873031616
# Step 115 of 170
# Epoch 1/5.. Train loss: 0.015.. Validation loss: 0.431.. Validation accuracy: 85.427%  ---  Time taken 18.368035078048706
# Step 116 of 170
# Epoch 1/5.. Train loss: 0.026.. Validation loss: 0.442.. Validation accuracy: 84.439%  ---  Time taken 18.085620641708374
# Step 117 of 170
# Epoch 1/5.. Train loss: 0.014.. Validation loss: 0.483.. Validation accuracy: 82.812%  ---  Time taken 18.50810170173645
# Step 118 of 170
# Epoch 1/5.. Train loss: 0.014.. Validation loss: 0.533.. Validation accuracy: 80.676%  ---  Time taken 18.21100950241089
# Step 119 of 170
# Epoch 1/5.. Train loss: 0.017.. Validation loss: 0.543.. Validation accuracy: 80.644%  ---  Time taken 18.408296823501587
# Step 120 of 170
# Epoch 1/5.. Train loss: 0.028.. Validation loss: 0.475.. Validation accuracy: 83.450%  ---  Time taken 18.431955575942993
# Step 121 of 170
# Epoch 1/5.. Train loss: 0.021.. Validation loss: 0.424.. Validation accuracy: 85.140%  ---  Time taken 18.03656816482544
# Step 122 of 170
# Epoch 1/5.. Train loss: 0.016.. Validation loss: 0.379.. Validation accuracy: 87.149%  ---  Time taken 18.335253715515137
# Step 123 of 170
# Epoch 1/5.. Train loss: 0.016.. Validation loss: 0.398.. Validation accuracy: 87.277%  ---  Time taken 18.06510615348816
# Step 124 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.441.. Validation accuracy: 85.204%  ---  Time taken 18.63856863975525
# Step 125 of 170
# Epoch 1/5.. Train loss: 0.019.. Validation loss: 0.428.. Validation accuracy: 85.969%  ---  Time taken 18.014572858810425
# Step 126 of 170
# Epoch 1/5.. Train loss: 0.019.. Validation loss: 0.395.. Validation accuracy: 87.659%  ---  Time taken 18.520955324172974
# Step 127 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.366.. Validation accuracy: 88.776%  ---  Time taken 18.19343662261963
# Step 128 of 170
# Epoch 1/5.. Train loss: 0.014.. Validation loss: 0.363.. Validation accuracy: 88.265%  ---  Time taken 18.40892267227173
# Step 129 of 170
# Epoch 1/5.. Train loss: 0.022.. Validation loss: 0.364.. Validation accuracy: 87.659%  ---  Time taken 18.030470848083496
# Step 130 of 170
# Epoch 1/5.. Train loss: 0.019.. Validation loss: 0.346.. Validation accuracy: 88.265%  ---  Time taken 18.5395405292511
# Step 131 of 170
# Epoch 1/5.. Train loss: 0.022.. Validation loss: 0.349.. Validation accuracy: 88.297%  ---  Time taken 18.148607969284058
# Step 132 of 170
# Epoch 1/5.. Train loss: 0.022.. Validation loss: 0.371.. Validation accuracy: 87.819%  ---  Time taken 18.589481353759766
# Step 133 of 170
# Epoch 1/5.. Train loss: 0.020.. Validation loss: 0.400.. Validation accuracy: 87.245%  ---  Time taken 18.22965359687805
# Step 134 of 170
# Epoch 1/5.. Train loss: 0.019.. Validation loss: 0.427.. Validation accuracy: 86.288%  ---  Time taken 18.507869958877563
# Step 135 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.439.. Validation accuracy: 85.714%  ---  Time taken 18.140456914901733
# Step 136 of 170
# Epoch 1/5.. Train loss: 0.016.. Validation loss: 0.426.. Validation accuracy: 86.480%  ---  Time taken 18.58003044128418
# Step 137 of 170
# Epoch 1/5.. Train loss: 0.017.. Validation loss: 0.408.. Validation accuracy: 86.320%  ---  Time taken 18.235633373260498
# Step 138 of 170
# Epoch 1/5.. Train loss: 0.016.. Validation loss: 0.386.. Validation accuracy: 87.309%  ---  Time taken 18.477975845336914
# Step 139 of 170
# Epoch 1/5.. Train loss: 0.016.. Validation loss: 0.367.. Validation accuracy: 88.170%  ---  Time taken 17.977675437927246
# Step 140 of 170
# Epoch 1/5.. Train loss: 0.013.. Validation loss: 0.351.. Validation accuracy: 89.062%  ---  Time taken 18.511381149291992
# Step 141 of 170
# Epoch 1/5.. Train loss: 0.016.. Validation loss: 0.352.. Validation accuracy: 88.839%  ---  Time taken 17.973570585250854
# Step 142 of 170
# Epoch 1/5.. Train loss: 0.017.. Validation loss: 0.358.. Validation accuracy: 88.712%  ---  Time taken 18.59415912628174
# Step 143 of 170
# Epoch 1/5.. Train loss: 0.015.. Validation loss: 0.365.. Validation accuracy: 88.297%  ---  Time taken 18.147645711898804
# Step 144 of 170
# Epoch 1/5.. Train loss: 0.017.. Validation loss: 0.348.. Validation accuracy: 88.776%  ---  Time taken 18.61235475540161
# Step 145 of 170
# Epoch 1/5.. Train loss: 0.012.. Validation loss: 0.350.. Validation accuracy: 88.520%  ---  Time taken 17.961575031280518
# Step 146 of 170
# Epoch 1/5.. Train loss: 0.016.. Validation loss: 0.386.. Validation accuracy: 87.022%  ---  Time taken 18.306429862976074
# Step 147 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.396.. Validation accuracy: 86.320%  ---  Time taken 18.029515981674194
# Step 148 of 170
# Epoch 1/5.. Train loss: 0.017.. Validation loss: 0.386.. Validation accuracy: 86.320%  ---  Time taken 18.334882020950317
# Step 149 of 170
# Epoch 1/5.. Train loss: 0.015.. Validation loss: 0.372.. Validation accuracy: 86.958%  ---  Time taken 18.148855686187744
# Step 150 of 170
# Epoch 1/5.. Train loss: 0.020.. Validation loss: 0.360.. Validation accuracy: 87.436%  ---  Time taken 18.31313419342041
# Step 151 of 170
# Epoch 1/5.. Train loss: 0.019.. Validation loss: 0.351.. Validation accuracy: 87.915%  ---  Time taken 18.165867805480957
# Step 152 of 170
# Epoch 1/5.. Train loss: 0.013.. Validation loss: 0.342.. Validation accuracy: 88.616%  ---  Time taken 18.23451590538025
# Step 153 of 170
# Epoch 1/5.. Train loss: 0.011.. Validation loss: 0.345.. Validation accuracy: 88.202%  ---  Time taken 18.304380178451538
# Step 154 of 170
# Epoch 1/5.. Train loss: 0.014.. Validation loss: 0.351.. Validation accuracy: 88.202%  ---  Time taken 18.171796560287476
# Step 155 of 170
# Epoch 1/5.. Train loss: 0.016.. Validation loss: 0.350.. Validation accuracy: 88.170%  ---  Time taken 18.2604341506958
# Step 156 of 170
# Epoch 1/5.. Train loss: 0.016.. Validation loss: 0.363.. Validation accuracy: 87.946%  ---  Time taken 18.09639048576355
# Step 157 of 170
# Epoch 1/5.. Train loss: 0.014.. Validation loss: 0.360.. Validation accuracy: 88.329%  ---  Time taken 18.447580575942993
# Step 158 of 170
# Epoch 1/5.. Train loss: 0.021.. Validation loss: 0.351.. Validation accuracy: 88.776%  ---  Time taken 18.068108558654785
# Step 159 of 170
# Epoch 1/5.. Train loss: 0.011.. Validation loss: 0.343.. Validation accuracy: 88.839%  ---  Time taken 18.50024175643921
# Step 160 of 170
# Epoch 1/5.. Train loss: 0.018.. Validation loss: 0.329.. Validation accuracy: 89.190%  ---  Time taken 18.017271041870117
# Step 161 of 170
# Epoch 1/5.. Train loss: 0.015.. Validation loss: 0.330.. Validation accuracy: 89.732%  ---  Time taken 18.408849477767944
# Step 162 of 170
# Epoch 1/5.. Train loss: 0.015.. Validation loss: 0.349.. Validation accuracy: 88.776%  ---  Time taken 18.082005262374878
# Step 163 of 170
# Epoch 1/5.. Train loss: 0.014.. Validation loss: 0.357.. Validation accuracy: 88.297%  ---  Time taken 18.451104879379272
# Step 164 of 170
# Epoch 1/5.. Train loss: 0.020.. Validation loss: 0.376.. Validation accuracy: 87.022%  ---  Time taken 18.0287823677063
# Step 165 of 170
# Epoch 1/5.. Train loss: 0.013.. Validation loss: 0.373.. Validation accuracy: 87.149%  ---  Time taken 18.52181649208069
# Step 166 of 170
# Epoch 1/5.. Train loss: 0.017.. Validation loss: 0.376.. Validation accuracy: 87.181%  ---  Time taken 18.050230979919434
# Step 167 of 170
# Epoch 1/5.. Train loss: 0.010.. Validation loss: 0.396.. Validation accuracy: 86.097%  ---  Time taken 18.46902060508728
# Step 168 of 170
# Epoch 1/5.. Train loss: 0.017.. Validation loss: 0.413.. Validation accuracy: 85.555%  ---  Time taken 18.015417337417603
# Step 169 of 170
# Epoch 1/5.. Train loss: 0.073.. Validation loss: 0.399.. Validation accuracy: 86.543%  ---  Time taken 18.63223648071289
# Step 0 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.805.. Validation accuracy: 70.695%  ---  Time taken 18.209412097930908
# Step 1 of 170
# Epoch 2/5.. Train loss: 0.035.. Validation loss: 1.126.. Validation accuracy: 60.268%  ---  Time taken 18.60040259361267
# Step 2 of 170
# Epoch 2/5.. Train loss: 0.046.. Validation loss: 0.799.. Validation accuracy: 70.440%  ---  Time taken 18.20267653465271
# Step 3 of 170
# Epoch 2/5.. Train loss: 0.038.. Validation loss: 0.525.. Validation accuracy: 81.218%  ---  Time taken 18.486541509628296
# Step 4 of 170
# Epoch 2/5.. Train loss: 0.019.. Validation loss: 0.500.. Validation accuracy: 81.824%  ---  Time taken 18.21509289741516
# Step 5 of 170
# Epoch 2/5.. Train loss: 0.022.. Validation loss: 0.590.. Validation accuracy: 77.997%  ---  Time taken 18.729305744171143
# Step 6 of 170
# Epoch 2/5.. Train loss: 0.016.. Validation loss: 0.742.. Validation accuracy: 75.287%  ---  Time taken 18.18736958503723
# Step 7 of 170
# Epoch 2/5.. Train loss: 0.023.. Validation loss: 0.892.. Validation accuracy: 72.927%  ---  Time taken 18.713306665420532
# Step 8 of 170
# Epoch 2/5.. Train loss: 0.023.. Validation loss: 1.041.. Validation accuracy: 70.918%  ---  Time taken 18.198854684829712
# Step 9 of 170
# Epoch 2/5.. Train loss: 0.039.. Validation loss: 1.060.. Validation accuracy: 69.420%  ---  Time taken 18.574979782104492
# Step 10 of 170
# Epoch 2/5.. Train loss: 0.035.. Validation loss: 0.990.. Validation accuracy: 69.515%  ---  Time taken 18.449300527572632
# Step 11 of 170
# Epoch 2/5.. Train loss: 0.038.. Validation loss: 0.814.. Validation accuracy: 72.417%  ---  Time taken 18.333232402801514
# Step 12 of 170
# Epoch 2/5.. Train loss: 0.026.. Validation loss: 0.670.. Validation accuracy: 76.531%  ---  Time taken 18.481847047805786
# Step 13 of 170
# Epoch 2/5.. Train loss: 0.021.. Validation loss: 0.555.. Validation accuracy: 81.122%  ---  Time taken 18.228820323944092
# Step 14 of 170
# Epoch 2/5.. Train loss: 0.022.. Validation loss: 0.497.. Validation accuracy: 85.045%  ---  Time taken 18.643054723739624
# Step 15 of 170
# Epoch 2/5.. Train loss: 0.021.. Validation loss: 0.487.. Validation accuracy: 86.352%  ---  Time taken 18.252894401550293
# Step 16 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.512.. Validation accuracy: 84.439%  ---  Time taken 18.681954383850098
# Step 17 of 170
# Epoch 2/5.. Train loss: 0.032.. Validation loss: 0.531.. Validation accuracy: 82.494%  ---  Time taken 18.29785132408142
# Step 18 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.540.. Validation accuracy: 81.154%  ---  Time taken 18.68059015274048
# Step 19 of 170
# Epoch 2/5.. Train loss: 0.021.. Validation loss: 0.559.. Validation accuracy: 80.835%  ---  Time taken 18.24461793899536
# Step 20 of 170
# Epoch 2/5.. Train loss: 0.022.. Validation loss: 0.563.. Validation accuracy: 81.282%  ---  Time taken 18.657877922058105
# Step 21 of 170
# Epoch 2/5.. Train loss: 0.022.. Validation loss: 0.553.. Validation accuracy: 82.175%  ---  Time taken 18.279678106307983
# Step 22 of 170
# Epoch 2/5.. Train loss: 0.021.. Validation loss: 0.539.. Validation accuracy: 82.717%  ---  Time taken 18.66866707801819
# Step 23 of 170
# Epoch 2/5.. Train loss: 0.016.. Validation loss: 0.504.. Validation accuracy: 83.642%  ---  Time taken 18.32262396812439
# Step 24 of 170
# Epoch 2/5.. Train loss: 0.021.. Validation loss: 0.477.. Validation accuracy: 84.917%  ---  Time taken 18.636586904525757
# Step 25 of 170
# Epoch 2/5.. Train loss: 0.017.. Validation loss: 0.440.. Validation accuracy: 85.810%  ---  Time taken 18.23467183113098
# Step 26 of 170
# Epoch 2/5.. Train loss: 0.024.. Validation loss: 0.431.. Validation accuracy: 85.395%  ---  Time taken 18.4885311126709
# Step 27 of 170
# Epoch 2/5.. Train loss: 0.022.. Validation loss: 0.453.. Validation accuracy: 84.726%  ---  Time taken 18.402531385421753
# Step 28 of 170
# Epoch 2/5.. Train loss: 0.015.. Validation loss: 0.498.. Validation accuracy: 82.015%  ---  Time taken 18.41915512084961
# Step 29 of 170
# Epoch 2/5.. Train loss: 0.025.. Validation loss: 0.502.. Validation accuracy: 81.665%  ---  Time taken 18.461677312850952
# Step 30 of 170
# Epoch 2/5.. Train loss: 0.025.. Validation loss: 0.472.. Validation accuracy: 83.673%  ---  Time taken 18.300715684890747
# Step 31 of 170
# Epoch 2/5.. Train loss: 0.016.. Validation loss: 0.457.. Validation accuracy: 84.534%  ---  Time taken 18.677932262420654
# Step 32 of 170
# Epoch 2/5.. Train loss: 0.017.. Validation loss: 0.428.. Validation accuracy: 86.320%  ---  Time taken 18.183889150619507
# Step 33 of 170
# Epoch 2/5.. Train loss: 0.015.. Validation loss: 0.408.. Validation accuracy: 87.117%  ---  Time taken 18.62490940093994
# Step 34 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.414.. Validation accuracy: 86.958%  ---  Time taken 18.167234897613525
# Step 35 of 170
# Epoch 2/5.. Train loss: 0.020.. Validation loss: 0.455.. Validation accuracy: 84.503%  ---  Time taken 18.669848918914795
# Step 36 of 170
# Epoch 2/5.. Train loss: 0.017.. Validation loss: 0.458.. Validation accuracy: 83.960%  ---  Time taken 18.228235960006714
# Step 37 of 170
# Epoch 2/5.. Train loss: 0.020.. Validation loss: 0.443.. Validation accuracy: 85.045%  ---  Time taken 18.657249689102173
# Step 38 of 170
# Epoch 2/5.. Train loss: 0.022.. Validation loss: 0.390.. Validation accuracy: 87.085%  ---  Time taken 18.27401089668274
# Step 39 of 170
# Epoch 2/5.. Train loss: 0.017.. Validation loss: 0.362.. Validation accuracy: 88.680%  ---  Time taken 18.595335483551025
# Step 40 of 170
# Epoch 2/5.. Train loss: 0.012.. Validation loss: 0.372.. Validation accuracy: 88.202%  ---  Time taken 18.278985261917114
# Step 41 of 170
# Epoch 2/5.. Train loss: 0.016.. Validation loss: 0.383.. Validation accuracy: 87.946%  ---  Time taken 18.51681900024414
# Step 42 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.387.. Validation accuracy: 88.106%  ---  Time taken 18.092100143432617
# Step 43 of 170
# Epoch 2/5.. Train loss: 0.017.. Validation loss: 0.403.. Validation accuracy: 87.532%  ---  Time taken 18.492795705795288
# Step 44 of 170
# Epoch 2/5.. Train loss: 0.020.. Validation loss: 0.396.. Validation accuracy: 87.787%  ---  Time taken 18.238956689834595
# Step 45 of 170
# Epoch 2/5.. Train loss: 0.022.. Validation loss: 0.405.. Validation accuracy: 86.511%  ---  Time taken 18.581393003463745
# Step 46 of 170
# Epoch 2/5.. Train loss: 0.019.. Validation loss: 0.417.. Validation accuracy: 85.523%  ---  Time taken 18.27454710006714
# Step 47 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.418.. Validation accuracy: 85.395%  ---  Time taken 18.254422187805176
# Step 48 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.427.. Validation accuracy: 84.885%  ---  Time taken 18.46783471107483
# Step 49 of 170
# Epoch 2/5.. Train loss: 0.016.. Validation loss: 0.445.. Validation accuracy: 84.694%  ---  Time taken 18.284626483917236
# Step 50 of 170
# Epoch 2/5.. Train loss: 0.017.. Validation loss: 0.466.. Validation accuracy: 84.024%  ---  Time taken 18.53820013999939
# Step 51 of 170
# Epoch 2/5.. Train loss: 0.022.. Validation loss: 0.466.. Validation accuracy: 84.630%  ---  Time taken 18.248465538024902
# Step 52 of 170
# Epoch 2/5.. Train loss: 0.017.. Validation loss: 0.426.. Validation accuracy: 86.033%  ---  Time taken 18.566742181777954
# Step 53 of 170
# Epoch 2/5.. Train loss: 0.023.. Validation loss: 0.395.. Validation accuracy: 87.213%  ---  Time taken 18.226120710372925
# Step 54 of 170
# Epoch 2/5.. Train loss: 0.015.. Validation loss: 0.377.. Validation accuracy: 87.659%  ---  Time taken 18.67840003967285
# Step 55 of 170
# Epoch 2/5.. Train loss: 0.020.. Validation loss: 0.376.. Validation accuracy: 87.915%  ---  Time taken 18.228711128234863
# Step 56 of 170
# Epoch 2/5.. Train loss: 0.022.. Validation loss: 0.359.. Validation accuracy: 88.552%  ---  Time taken 18.67368769645691
# Step 57 of 170
# Epoch 2/5.. Train loss: 0.025.. Validation loss: 0.360.. Validation accuracy: 88.807%  ---  Time taken 18.222172498703003
# Step 58 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.361.. Validation accuracy: 88.871%  ---  Time taken 18.676928997039795
# Step 59 of 170
# Epoch 2/5.. Train loss: 0.011.. Validation loss: 0.389.. Validation accuracy: 87.532%  ---  Time taken 18.04013466835022
# Step 60 of 170
# Epoch 2/5.. Train loss: 0.015.. Validation loss: 0.419.. Validation accuracy: 86.320%  ---  Time taken 18.52308750152588
# Step 61 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.459.. Validation accuracy: 84.343%  ---  Time taken 18.24462652206421
# Step 62 of 170
# Epoch 2/5.. Train loss: 0.027.. Validation loss: 0.436.. Validation accuracy: 85.077%  ---  Time taken 18.64661455154419
# Step 63 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.411.. Validation accuracy: 86.193%  ---  Time taken 18.246652841567993
# Step 64 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.407.. Validation accuracy: 86.384%  ---  Time taken 18.54404640197754
# Step 65 of 170
# Epoch 2/5.. Train loss: 0.019.. Validation loss: 0.406.. Validation accuracy: 86.830%  ---  Time taken 18.333902597427368
# Step 66 of 170
# Epoch 2/5.. Train loss: 0.011.. Validation loss: 0.421.. Validation accuracy: 86.480%  ---  Time taken 18.52898621559143
# Step 67 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.430.. Validation accuracy: 85.300%  ---  Time taken 18.506880283355713
# Step 68 of 170
# Epoch 2/5.. Train loss: 0.013.. Validation loss: 0.414.. Validation accuracy: 85.300%  ---  Time taken 18.096508741378784
# Step 69 of 170
# Epoch 2/5.. Train loss: 0.020.. Validation loss: 0.389.. Validation accuracy: 86.926%  ---  Time taken 18.789526224136353
# Step 70 of 170
# Epoch 2/5.. Train loss: 0.015.. Validation loss: 0.373.. Validation accuracy: 87.436%  ---  Time taken 18.25069761276245
# Step 71 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.380.. Validation accuracy: 87.309%  ---  Time taken 18.72987413406372
# Step 72 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.394.. Validation accuracy: 86.575%  ---  Time taken 18.20184898376465
# Step 73 of 170
# Epoch 2/5.. Train loss: 0.019.. Validation loss: 0.408.. Validation accuracy: 85.938%  ---  Time taken 18.635690689086914
# Step 74 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.398.. Validation accuracy: 87.181%  ---  Time taken 18.210748434066772
# Step 75 of 170
# Epoch 2/5.. Train loss: 0.016.. Validation loss: 0.407.. Validation accuracy: 87.117%  ---  Time taken 18.676013708114624
# Step 76 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.419.. Validation accuracy: 85.746%  ---  Time taken 18.22832179069519
# Step 77 of 170
# Epoch 2/5.. Train loss: 0.024.. Validation loss: 0.420.. Validation accuracy: 85.268%  ---  Time taken 18.6020565032959
# Step 78 of 170
# Epoch 2/5.. Train loss: 0.025.. Validation loss: 0.395.. Validation accuracy: 86.607%  ---  Time taken 18.164342880249023
# Step 79 of 170
# Epoch 2/5.. Train loss: 0.016.. Validation loss: 0.392.. Validation accuracy: 86.288%  ---  Time taken 18.656869888305664
# Step 80 of 170
# Epoch 2/5.. Train loss: 0.015.. Validation loss: 0.395.. Validation accuracy: 86.224%  ---  Time taken 18.191402673721313
# Step 81 of 170
# Epoch 2/5.. Train loss: 0.022.. Validation loss: 0.390.. Validation accuracy: 87.085%  ---  Time taken 18.692087411880493
# Step 82 of 170
# Epoch 2/5.. Train loss: 0.016.. Validation loss: 0.378.. Validation accuracy: 87.404%  ---  Time taken 18.40150499343872
# Step 83 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.357.. Validation accuracy: 88.010%  ---  Time taken 18.50687575340271
# Step 84 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.340.. Validation accuracy: 88.712%  ---  Time taken 18.47213053703308
# Step 85 of 170
# Epoch 2/5.. Train loss: 0.011.. Validation loss: 0.329.. Validation accuracy: 89.381%  ---  Time taken 18.29709029197693
# Step 86 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.324.. Validation accuracy: 89.158%  ---  Time taken 18.646008014678955
# Step 87 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.338.. Validation accuracy: 89.254%  ---  Time taken 18.242172479629517
# Step 88 of 170
# Epoch 2/5.. Train loss: 0.008.. Validation loss: 0.349.. Validation accuracy: 88.552%  ---  Time taken 18.67971897125244
# Step 89 of 170
# Epoch 2/5.. Train loss: 0.011.. Validation loss: 0.372.. Validation accuracy: 87.883%  ---  Time taken 18.227639198303223
# Step 90 of 170
# Epoch 2/5.. Train loss: 0.015.. Validation loss: 0.397.. Validation accuracy: 86.862%  ---  Time taken 18.596096992492676
# Step 91 of 170
# Epoch 2/5.. Train loss: 0.016.. Validation loss: 0.397.. Validation accuracy: 86.543%  ---  Time taken 18.269208431243896
# Step 92 of 170
# Epoch 2/5.. Train loss: 0.010.. Validation loss: 0.375.. Validation accuracy: 87.564%  ---  Time taken 18.734025239944458
# Step 93 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.340.. Validation accuracy: 88.744%  ---  Time taken 18.159664392471313
# Step 94 of 170
# Epoch 2/5.. Train loss: 0.013.. Validation loss: 0.321.. Validation accuracy: 89.254%  ---  Time taken 18.66388773918152
# Step 95 of 170
# Epoch 2/5.. Train loss: 0.025.. Validation loss: 0.320.. Validation accuracy: 88.935%  ---  Time taken 18.203824758529663
# Step 96 of 170
# Epoch 2/5.. Train loss: 0.020.. Validation loss: 0.328.. Validation accuracy: 88.712%  ---  Time taken 18.70356774330139
# Step 97 of 170
# Epoch 2/5.. Train loss: 0.017.. Validation loss: 0.321.. Validation accuracy: 89.190%  ---  Time taken 18.232529401779175
# Step 98 of 170
# Epoch 2/5.. Train loss: 0.013.. Validation loss: 0.321.. Validation accuracy: 89.445%  ---  Time taken 18.55692434310913
# Step 99 of 170
# Epoch 2/5.. Train loss: 0.019.. Validation loss: 0.323.. Validation accuracy: 89.318%  ---  Time taken 18.348957061767578
# Step 100 of 170
# Epoch 2/5.. Train loss: 0.016.. Validation loss: 0.328.. Validation accuracy: 88.616%  ---  Time taken 18.46179437637329
# Step 101 of 170
# Epoch 2/5.. Train loss: 0.011.. Validation loss: 0.341.. Validation accuracy: 88.170%  ---  Time taken 18.577862977981567
# Step 102 of 170
# Epoch 2/5.. Train loss: 0.013.. Validation loss: 0.367.. Validation accuracy: 87.596%  ---  Time taken 18.386810302734375
# Step 103 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.375.. Validation accuracy: 87.277%  ---  Time taken 18.59767985343933
# Step 104 of 170
# Epoch 2/5.. Train loss: 0.013.. Validation loss: 0.372.. Validation accuracy: 87.468%  ---  Time taken 18.293006658554077
# Step 105 of 170
# Epoch 2/5.. Train loss: 0.017.. Validation loss: 0.357.. Validation accuracy: 88.233%  ---  Time taken 18.695509672164917
# Step 106 of 170
# Epoch 2/5.. Train loss: 0.020.. Validation loss: 0.354.. Validation accuracy: 88.106%  ---  Time taken 18.200650453567505
# Step 107 of 170
# Epoch 2/5.. Train loss: 0.017.. Validation loss: 0.352.. Validation accuracy: 88.265%  ---  Time taken 18.617690086364746
# Step 108 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.353.. Validation accuracy: 88.329%  ---  Time taken 18.15490698814392
# Step 109 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.352.. Validation accuracy: 88.680%  ---  Time taken 18.684733152389526
# Step 110 of 170
# Epoch 2/5.. Train loss: 0.012.. Validation loss: 0.353.. Validation accuracy: 88.712%  ---  Time taken 18.252615213394165
# Step 111 of 170
# Epoch 2/5.. Train loss: 0.024.. Validation loss: 0.339.. Validation accuracy: 89.062%  ---  Time taken 18.622497081756592
# Step 112 of 170
# Epoch 2/5.. Train loss: 0.009.. Validation loss: 0.347.. Validation accuracy: 88.361%  ---  Time taken 18.286420106887817
# Step 113 of 170
# Epoch 2/5.. Train loss: 0.016.. Validation loss: 0.358.. Validation accuracy: 87.819%  ---  Time taken 18.6054265499115
# Step 114 of 170
# Epoch 2/5.. Train loss: 0.021.. Validation loss: 0.358.. Validation accuracy: 87.946%  ---  Time taken 18.127686500549316
# Step 115 of 170
# Epoch 2/5.. Train loss: 0.013.. Validation loss: 0.344.. Validation accuracy: 88.425%  ---  Time taken 18.64303684234619
# Step 116 of 170
# Epoch 2/5.. Train loss: 0.015.. Validation loss: 0.334.. Validation accuracy: 88.712%  ---  Time taken 18.131391286849976
# Step 117 of 170
# Epoch 2/5.. Train loss: 0.017.. Validation loss: 0.328.. Validation accuracy: 89.381%  ---  Time taken 18.622732639312744
# Step 118 of 170
# Epoch 2/5.. Train loss: 0.022.. Validation loss: 0.338.. Validation accuracy: 88.967%  ---  Time taken 18.424689769744873
# Step 119 of 170
# Epoch 2/5.. Train loss: 0.017.. Validation loss: 0.344.. Validation accuracy: 88.935%  ---  Time taken 18.41775107383728
# Step 120 of 170
# Epoch 2/5.. Train loss: 0.011.. Validation loss: 0.382.. Validation accuracy: 87.309%  ---  Time taken 18.539161682128906
# Step 121 of 170
# Epoch 2/5.. Train loss: 0.015.. Validation loss: 0.415.. Validation accuracy: 85.969%  ---  Time taken 18.210439682006836
# Step 122 of 170
# Epoch 2/5.. Train loss: 0.019.. Validation loss: 0.442.. Validation accuracy: 84.726%  ---  Time taken 18.67731785774231
# Step 123 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.454.. Validation accuracy: 83.833%  ---  Time taken 18.200217962265015
# Step 124 of 170
# Epoch 2/5.. Train loss: 0.017.. Validation loss: 0.455.. Validation accuracy: 84.024%  ---  Time taken 18.61246085166931
# Step 125 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.451.. Validation accuracy: 83.865%  ---  Time taken 18.270169973373413
# Step 126 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.430.. Validation accuracy: 85.077%  ---  Time taken 18.6234450340271
# Step 127 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.392.. Validation accuracy: 86.384%  ---  Time taken 18.284124612808228
# Step 128 of 170
# Epoch 2/5.. Train loss: 0.017.. Validation loss: 0.368.. Validation accuracy: 87.436%  ---  Time taken 18.622625827789307
# Step 129 of 170
# Epoch 2/5.. Train loss: 0.010.. Validation loss: 0.357.. Validation accuracy: 88.233%  ---  Time taken 18.176676273345947
# Step 130 of 170
# Epoch 2/5.. Train loss: 0.016.. Validation loss: 0.347.. Validation accuracy: 88.361%  ---  Time taken 18.66967511177063
# Step 131 of 170
# Epoch 2/5.. Train loss: 0.012.. Validation loss: 0.335.. Validation accuracy: 89.222%  ---  Time taken 18.184982538223267
# Step 132 of 170
# Epoch 2/5.. Train loss: 0.013.. Validation loss: 0.331.. Validation accuracy: 89.062%  ---  Time taken 18.670391082763672
# Step 133 of 170
# Epoch 2/5.. Train loss: 0.021.. Validation loss: 0.337.. Validation accuracy: 88.935%  ---  Time taken 18.295719385147095
# Step 134 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.343.. Validation accuracy: 88.489%  ---  Time taken 18.600078105926514
# Step 135 of 170
# Epoch 2/5.. Train loss: 0.016.. Validation loss: 0.323.. Validation accuracy: 89.126%  ---  Time taken 18.355089902877808
# Step 136 of 170
# Epoch 2/5.. Train loss: 0.010.. Validation loss: 0.317.. Validation accuracy: 89.668%  ---  Time taken 18.53561234474182
# Step 137 of 170
# Epoch 2/5.. Train loss: 0.012.. Validation loss: 0.321.. Validation accuracy: 89.636%  ---  Time taken 18.481786489486694
# Step 138 of 170
# Epoch 2/5.. Train loss: 0.012.. Validation loss: 0.324.. Validation accuracy: 89.445%  ---  Time taken 18.316508054733276
# Step 139 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.331.. Validation accuracy: 89.349%  ---  Time taken 18.64380168914795
# Step 140 of 170
# Epoch 2/5.. Train loss: 0.016.. Validation loss: 0.335.. Validation accuracy: 89.413%  ---  Time taken 18.27324342727661
# Step 141 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.332.. Validation accuracy: 89.923%  ---  Time taken 18.63497805595398
# Step 142 of 170
# Epoch 2/5.. Train loss: 0.008.. Validation loss: 0.324.. Validation accuracy: 89.764%  ---  Time taken 18.20594835281372
# Step 143 of 170
# Epoch 2/5.. Train loss: 0.016.. Validation loss: 0.322.. Validation accuracy: 89.541%  ---  Time taken 18.619628429412842
# Step 144 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.333.. Validation accuracy: 88.903%  ---  Time taken 18.238122940063477
# Step 145 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.329.. Validation accuracy: 88.935%  ---  Time taken 18.750595569610596
# Step 146 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.328.. Validation accuracy: 88.871%  ---  Time taken 18.399081230163574
# Step 147 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.320.. Validation accuracy: 89.158%  ---  Time taken 18.74443745613098
# Step 148 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.318.. Validation accuracy: 88.903%  ---  Time taken 18.307430744171143
# Step 149 of 170
# Epoch 2/5.. Train loss: 0.009.. Validation loss: 0.311.. Validation accuracy: 89.509%  ---  Time taken 18.720402717590332
# Step 150 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.313.. Validation accuracy: 89.955%  ---  Time taken 18.249500036239624
# Step 151 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.307.. Validation accuracy: 90.497%  ---  Time taken 18.56421160697937
# Step 152 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.313.. Validation accuracy: 90.242%  ---  Time taken 18.376805305480957
# Step 153 of 170
# Epoch 2/5.. Train loss: 0.010.. Validation loss: 0.319.. Validation accuracy: 89.860%  ---  Time taken 18.471898794174194
# Step 154 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.314.. Validation accuracy: 89.860%  ---  Time taken 18.78838348388672
# Step 155 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.309.. Validation accuracy: 90.179%  ---  Time taken 18.568786144256592
# Step 156 of 170
# Epoch 2/5.. Train loss: 0.016.. Validation loss: 0.320.. Validation accuracy: 89.445%  ---  Time taken 19.044352054595947
# Step 157 of 170
# Epoch 2/5.. Train loss: 0.012.. Validation loss: 0.333.. Validation accuracy: 89.158%  ---  Time taken 18.429255723953247
# Step 158 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.349.. Validation accuracy: 88.648%  ---  Time taken 18.758833408355713
# Step 159 of 170
# Epoch 2/5.. Train loss: 0.022.. Validation loss: 0.348.. Validation accuracy: 88.648%  ---  Time taken 18.387995719909668
# Step 160 of 170
# Epoch 2/5.. Train loss: 0.012.. Validation loss: 0.339.. Validation accuracy: 89.222%  ---  Time taken 18.763967275619507
# Step 161 of 170
# Epoch 2/5.. Train loss: 0.008.. Validation loss: 0.346.. Validation accuracy: 88.393%  ---  Time taken 18.323827266693115
# Step 162 of 170
# Epoch 2/5.. Train loss: 0.019.. Validation loss: 0.355.. Validation accuracy: 88.170%  ---  Time taken 18.70068383216858
# Step 163 of 170
# Epoch 2/5.. Train loss: 0.016.. Validation loss: 0.347.. Validation accuracy: 88.552%  ---  Time taken 18.419106245040894
# Step 164 of 170
# Epoch 2/5.. Train loss: 0.009.. Validation loss: 0.325.. Validation accuracy: 89.286%  ---  Time taken 18.772284030914307
# Step 165 of 170
# Epoch 2/5.. Train loss: 0.011.. Validation loss: 0.308.. Validation accuracy: 90.051%  ---  Time taken 18.497267961502075
# Step 166 of 170
# Epoch 2/5.. Train loss: 0.018.. Validation loss: 0.298.. Validation accuracy: 90.753%  ---  Time taken 18.353110551834106
# Step 167 of 170
# Epoch 2/5.. Train loss: 0.015.. Validation loss: 0.297.. Validation accuracy: 90.210%  ---  Time taken 18.621644735336304
# Step 168 of 170
# Epoch 2/5.. Train loss: 0.014.. Validation loss: 0.305.. Validation accuracy: 89.605%  ---  Time taken 18.26964497566223
# Step 169 of 170
# Epoch 2/5.. Train loss: 0.057.. Validation loss: 0.438.. Validation accuracy: 85.108%  ---  Time taken 18.57138419151306
# Step 0 of 170
# Epoch 3/5.. Train loss: 0.025.. Validation loss: 0.660.. Validation accuracy: 76.531%  ---  Time taken 18.32674789428711
# Step 1 of 170
# Epoch 3/5.. Train loss: 0.033.. Validation loss: 0.753.. Validation accuracy: 73.374%  ---  Time taken 18.81684947013855
# Step 2 of 170
# Epoch 3/5.. Train loss: 0.026.. Validation loss: 0.663.. Validation accuracy: 76.371%  ---  Time taken 18.23602533340454
# Step 3 of 170
# Epoch 3/5.. Train loss: 0.025.. Validation loss: 0.527.. Validation accuracy: 81.154%  ---  Time taken 18.724440574645996
# Step 4 of 170
# Epoch 3/5.. Train loss: 0.027.. Validation loss: 0.454.. Validation accuracy: 84.503%  ---  Time taken 18.20664668083191
# Step 5 of 170
# Epoch 3/5.. Train loss: 0.016.. Validation loss: 0.448.. Validation accuracy: 84.726%  ---  Time taken 18.67392086982727
# Step 6 of 170
# Epoch 3/5.. Train loss: 0.014.. Validation loss: 0.452.. Validation accuracy: 84.343%  ---  Time taken 18.360881090164185
# Step 7 of 170
# Epoch 3/5.. Train loss: 0.026.. Validation loss: 0.465.. Validation accuracy: 83.865%  ---  Time taken 18.688558340072632
# Step 8 of 170
# Epoch 3/5.. Train loss: 0.024.. Validation loss: 0.439.. Validation accuracy: 85.491%  ---  Time taken 18.281824827194214
# Step 9 of 170
# Epoch 3/5.. Train loss: 0.018.. Validation loss: 0.411.. Validation accuracy: 86.575%  ---  Time taken 18.589239358901978
# Step 10 of 170
# ...
# Step 29 of 170
# Epoch 3/5.. Train loss: 0.011.. Validation loss: 0.323.. Validation accuracy: 89.286%  ---  Time taken 18.368781805038452
# Step 30 of 170
# Epoch 3/5.. Train loss: 0.018.. Validation loss: 0.320.. Validation accuracy: 89.286%  ---  Time taken 18.719133377075195
# Step 31 of 170
# Epoch 3/5.. Train loss: 0.013.. Validation loss: 0.321.. Validation accuracy: 89.349%  ---  Time taken 18.49850058555603
# Step 32 of 170
# Epoch 3/5.. Train loss: 0.010.. Validation loss: 0.311.. Validation accuracy: 89.955%  ---  Time taken 18.699488401412964
# Step 33 of 170
# Epoch 3/5.. Train loss: 0.012.. Validation loss: 0.313.. Validation accuracy: 89.605%  ---  Time taken 18.671732425689697
# Step 34 of 170
# Epoch 3/5.. Train loss: 0.016.. Validation loss: 0.310.. Validation accuracy: 90.051%  ---  Time taken 18.535828828811646
# Step 35 of 170
# Epoch 3/5.. Train loss: 0.010.. Validation loss: 0.321.. Validation accuracy: 89.477%  ---  Time taken 18.92942523956299
# Step 36 of 170
# Epoch 3/5.. Train loss: 0.019.. Validation loss: 0.331.. Validation accuracy: 88.807%  ---  Time taken 18.21097207069397
# Step 37 of 170
# Epoch 3/5.. Train loss: 0.013.. Validation loss: 0.341.. Validation accuracy: 88.648%  ---  Time taken 18.664137363433838
# Step 38 of 170
# Epoch 3/5.. Train loss: 0.009.. Validation loss: 0.348.. Validation accuracy: 88.265%  ---  Time taken 18.215503931045532
# Step 39 of 170
# Epoch 3/5.. Train loss: 0.014.. Validation loss: 0.350.. Validation accuracy: 88.010%  ---  Time taken 18.842183589935303
# Step 40 of 170
# Epoch 3/5.. Train loss: 0.018.. Validation loss: 0.342.. Validation accuracy: 88.520%  ---  Time taken 18.362645864486694
# Step 41 of 170
# Epoch 3/5.. Train loss: 0.017.. Validation loss: 0.333.. Validation accuracy: 88.935%  ---  Time taken 18.695797443389893
# Step 42 of 170
# Epoch 3/5.. Train loss: 0.014.. Validation loss: 0.326.. Validation accuracy: 89.062%  ---  Time taken 18.32873558998108
# Step 43 of 170
# Epoch 3/5.. Train loss: 0.017.. Validation loss: 0.313.. Validation accuracy: 89.828%  ---  Time taken 18.68368172645569
# Step 44 of 170
# Epoch 3/5.. Train loss: 0.013.. Validation loss: 0.312.. Validation accuracy: 90.019%  ---  Time taken 18.273333072662354
# Step 45 of 170
# Epoch 3/5.. Train loss: 0.013.. Validation loss: 0.334.. Validation accuracy: 88.903%  ---  Time taken 18.816598653793335
# Step 46 of 170
# Epoch 3/5.. Train loss: 0.009.. Validation loss: 0.370.. Validation accuracy: 87.181%  ---  Time taken 18.354748725891113
# Step 47 of 170
# Epoch 3/5.. Train loss: 0.019.. Validation loss: 0.379.. Validation accuracy: 86.288%  ---  Time taken 19.005852937698364
# Step 48 of 170
# Epoch 3/5.. Train loss: 0.022.. Validation loss: 0.391.. Validation accuracy: 86.065%  ---  Time taken 18.55403232574463
# Step 49 of 170
# Epoch 3/5.. Train loss: 0.014.. Validation loss: 0.394.. Validation accuracy: 86.352%  ---  Time taken 18.357954740524292
# Step 50 of 170
# Epoch 3/5.. Train loss: 0.017.. Validation loss: 0.377.. Validation accuracy: 86.958%  ---  Time taken 18.743267059326172
# Step 51 of 170
# Epoch 3/5.. Train loss: 0.014.. Validation loss: 0.352.. Validation accuracy: 87.723%  ---  Time taken 18.320130825042725
# Step 52 of 170
# Epoch 3/5.. Train loss: 0.014.. Validation loss: 0.336.. Validation accuracy: 88.744%  ---  Time taken 18.74309468269348
# Step 53 of 170
# Epoch 3/5.. Train loss: 0.015.. Validation loss: 0.325.. Validation accuracy: 89.222%  ---  Time taken 18.264827966690063
# Step 54 of 170
# Epoch 3/5.. Train loss: 0.014.. Validation loss: 0.309.. Validation accuracy: 89.923%  ---  Time taken 18.704402208328247
# Step 55 of 170
# Epoch 3/5.. Train loss: 0.012.. Validation loss: 0.301.. Validation accuracy: 90.784%  ---  Time taken 18.28821873664856
# Step 56 of 170
# Epoch 3/5.. Train loss: 0.015.. Validation loss: 0.301.. Validation accuracy: 90.721%  ---  Time taken 18.775996923446655
# Step 57 of 170
# Epoch 3/5.. Train loss: 0.015.. Validation loss: 0.317.. Validation accuracy: 90.051%  ---  Time taken 18.160025596618652
# Step 58 of 170
# Epoch 3/5.. Train loss: 0.022.. Validation loss: 0.321.. Validation accuracy: 89.955%  ---  Time taken 18.74747323989868
# Step 59 of 170
# Epoch 3/5.. Train loss: 0.008.. Validation loss: 0.334.. Validation accuracy: 89.222%  ---  Time taken 18.23725152015686
# Step 60 of 170
# Epoch 3/5.. Train loss: 0.015.. Validation loss: 0.340.. Validation accuracy: 88.967%  ---  Time taken 18.739992380142212
# Step 61 of 170
# Epoch 3/5.. Train loss: 0.014.. Validation loss: 0.334.. Validation accuracy: 89.126%  ---  Time taken 18.31356930732727
# Step 62 of 170
# Epoch 3/5.. Train loss: 0.013.. Validation loss: 0.339.. Validation accuracy: 88.712%  ---  Time taken 18.647400856018066
# Step 63 of 170
# Epoch 3/5.. Train loss: 0.015.. Validation loss: 0.336.. Validation accuracy: 88.903%  ---  Time taken 18.5390727519989
# Step 64 of 170
# Epoch 3/5.. Train loss: 0.014.. Validation loss: 0.319.. Validation accuracy: 89.573%  ---  Time taken 18.54434299468994
# Step 65 of 170
# Epoch 3/5.. Train loss: 0.016.. Validation loss: 0.302.. Validation accuracy: 90.115%  ---  Time taken 19.095417022705078
# Step 66 of 170
# Epoch 3/5.. Train loss: 0.014.. Validation loss: 0.290.. Validation accuracy: 90.848%  ---  Time taken 18.669520616531372
# Step 67 of 170
# Epoch 3/5.. Train loss: 0.010.. Validation loss: 0.281.. Validation accuracy: 90.880%  ---  Time taken 18.794290781021118
# Step 68 of 170
# Epoch 3/5.. Train loss: 0.017.. Validation loss: 0.288.. Validation accuracy: 90.529%  ---  Time taken 18.39787769317627
# Step 69 of 170
# Epoch 3/5.. Train loss: 0.011.. Validation loss: 0.314.. Validation accuracy: 89.605%  ---  Time taken 18.706056356430054
# Step 70 of 170
# Epoch 3/5.. Train loss: 0.012.. Validation loss: 0.323.. Validation accuracy: 88.839%  ---  Time taken 18.280884742736816
# Step 71 of 170
# Epoch 3/5.. Train loss: 0.015.. Validation loss: 0.342.. Validation accuracy: 87.787%  ---  Time taken 18.70234441757202
# Step 72 of 170
# Epoch 3/5.. Train loss: 0.011.. Validation loss: 0.339.. Validation accuracy: 87.978%  ---  Time taken 18.25255799293518
# Step 73 of 170
# Epoch 3/5.. Train loss: 0.017.. Validation loss: 0.298.. Validation accuracy: 90.115%  ---  Time taken 18.71571946144104
# Step 74 of 170
# Epoch 3/5.. Train loss: 0.018.. Validation loss: 0.283.. Validation accuracy: 90.625%  ---  Time taken 18.241676092147827
# Step 75 of 170
# Epoch 3/5.. Train loss: 0.018.. Validation loss: 0.285.. Validation accuracy: 90.402%  ---  Time taken 18.56428861618042
# Step 76 of 170
# Epoch 3/5.. Train loss: 0.009.. Validation loss: 0.313.. Validation accuracy: 88.967%  ---  Time taken 18.180700063705444
# Step 77 of 170
# Epoch 3/5.. Train loss: 0.013.. Validation loss: 0.343.. Validation accuracy: 87.915%  ---  Time taken 18.664644479751587
# Step 78 of 170
# Epoch 3/5.. Train loss: 0.018.. Validation loss: 0.352.. Validation accuracy: 87.596%  ---  Time taken 18.497997045516968
# Step 79 of 170
# Epoch 3/5.. Train loss: 0.017.. Validation loss: 0.336.. Validation accuracy: 88.393%  ---  Time taken 18.327644109725952
# Step 80 of 170
# Epoch 3/5.. Train loss: 0.017.. Validation loss: 0.308.. Validation accuracy: 89.031%  ---  Time taken 18.651759386062622
# Step 81 of 170
# Epoch 3/5.. Train loss: 0.014.. Validation loss: 0.286.. Validation accuracy: 90.434%  ---  Time taken 18.209552526474
# Step 82 of 170
# Epoch 3/5.. Train loss: 0.011.. Validation loss: 0.286.. Validation accuracy: 90.625%  ---  Time taken 18.63369655609131
# Step 83 of 170
# Epoch 3/5.. Train loss: 0.016.. Validation loss: 0.295.. Validation accuracy: 90.753%  ---  Time taken 18.338674783706665
# Step 84 of 170
# Epoch 3/5.. Train loss: 0.010.. Validation loss: 0.314.. Validation accuracy: 89.668%  ---  Time taken 18.70712375640869
# Step 85 of 170
# Epoch 3/5.. Train loss: 0.010.. Validation loss: 0.314.. Validation accuracy: 89.732%  ---  Time taken 18.2745521068573
# Step 86 of 170
# Epoch 3/5.. Train loss: 0.013.. Validation loss: 0.307.. Validation accuracy: 89.764%  ---  Time taken 18.691800355911255
# Step 87 of 170
# Epoch 3/5.. Train loss: 0.009.. Validation loss: 0.294.. Validation accuracy: 89.892%  ---  Time taken 18.21609854698181
# Step 88 of 170
# Epoch 3/5.. Train loss: 0.011.. Validation loss: 0.297.. Validation accuracy: 90.083%  ---  Time taken 18.6579167842865
# Step 89 of 170
# Epoch 3/5.. Train loss: 0.013.. Validation loss: 0.296.. Validation accuracy: 90.115%  ---  Time taken 18.11178946495056
# Step 90 of 170
# Epoch 3/5.. Train loss: 0.017.. Validation loss: 0.292.. Validation accuracy: 90.370%  ---  Time taken 18.49176049232483
# Step 91 of 170
# Epoch 3/5.. Train loss: 0.016.. Validation loss: 0.286.. Validation accuracy: 90.784%  ---  Time taken 18.159305334091187
# Step 92 of 170
# Epoch 3/5.. Train loss: 0.016.. Validation loss: 0.283.. Validation accuracy: 90.242%  ---  Time taken 18.540550708770752
# Step 93 of 170
# Epoch 3/5.. Train loss: 0.015.. Validation loss: 0.303.. Validation accuracy: 89.445%  ---  Time taken 18.12079620361328
# Step 94 of 170
# Epoch 3/5.. Train loss: 0.011.. Validation loss: 0.322.. Validation accuracy: 88.584%  ---  Time taken 18.506335258483887
# Step 95 of 170
# Epoch 3/5.. Train loss: 0.010.. Validation loss: 0.348.. Validation accuracy: 87.883%  ---  Time taken 18.055179357528687
# Step 96 of 170
# Epoch 3/5.. Train loss: 0.022.. Validation loss: 0.343.. Validation accuracy: 88.010%  ---  Time taken 18.601558685302734
# Step 97 of 170
# Epoch 3/5.. Train loss: 0.016.. Validation loss: 0.328.. Validation accuracy: 88.584%  ---  Time taken 18.29910445213318
# Step 98 of 170
# Epoch 3/5.. Train loss: 0.014.. Validation loss: 0.306.. Validation accuracy: 89.573%  ---  Time taken 18.473649740219116
# Step 99 of 170
# Epoch 3/5.. Train loss: 0.016.. Validation loss: 0.306.. Validation accuracy: 89.605%  ---  Time taken 18.512490272521973
# Step 100 of 170
# Epoch 3/5.. Train loss: 0.013.. Validation loss: 0.306.. Validation accuracy: 89.668%  ---  Time taken 18.300795316696167
# Step 101 of 170
# Epoch 3/5.. Train loss: 0.010.. Validation loss: 0.310.. Validation accuracy: 89.318%  ---  Time taken 18.654725790023804
# Step 102 of 170
# Epoch 3/5.. Train loss: 0.015.. Validation loss: 0.328.. Validation accuracy: 88.839%  ---  Time taken 18.264134645462036
# Step 103 of 170
# Epoch 3/5.. Train loss: 0.018.. Validation loss: 0.327.. Validation accuracy: 88.744%  ---  Time taken 18.65942883491516
# Step 104 of 170
# Epoch 3/5.. Train loss: 0.016.. Validation loss: 0.327.. Validation accuracy: 88.935%  ---  Time taken 18.271778106689453
# Step 105 of 170
# Epoch 3/5.. Train loss: 0.014.. Validation loss: 0.332.. Validation accuracy: 89.126%  ---  Time taken 18.703117847442627
# Step 106 of 170
# Epoch 3/5.. Train loss: 0.013.. Validation loss: 0.335.. Validation accuracy: 88.425%  ---  Time taken 18.218082904815674
# Step 107 of 170
# Epoch 3/5.. Train loss: 0.011.. Validation loss: 0.331.. Validation accuracy: 88.138%  ---  Time taken 18.71656560897827
# Step 108 of 170
# Epoch 3/5.. Train loss: 0.015.. Validation loss: 0.327.. Validation accuracy: 88.776%  ---  Time taken 18.26540207862854
# Step 109 of 170
# Epoch 3/5.. Train loss: 0.012.. Validation loss: 0.325.. Validation accuracy: 88.967%  ---  Time taken 18.696717977523804
# Step 110 of 170
# Epoch 3/5.. Train loss: 0.019.. Validation loss: 0.311.. Validation accuracy: 89.955%  ---  Time taken 18.181841611862183
# Step 111 of 170
# Epoch 3/5.. Train loss: 0.009.. Validation loss: 0.306.. Validation accuracy: 90.179%  ---  Time taken 18.69565486907959
# Step 112 of 170
# Epoch 3/5.. Train loss: 0.011.. Validation loss: 0.292.. Validation accuracy: 90.370%  ---  Time taken 18.22692370414734
# Step 113 of 170
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-c514e9c624a3> in <cell line: 6>()
#      32             model.eval()
#      33             with torch.no_grad():
# ---> 34                 for images, labels in validation_loader:
#      35
#      36                     images, labels = images.to(device), labels.to(
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     631                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     632                 self._reset()  # type: ignore[call-arg]
# --> 633             data = self._next_data()
#     634             self._num_yielded += 1
#     635             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     675     def _next_data(self):
#     676         index = self._next_index()  # may raise StopIteration
# --> 677         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     678         if self._pin_memory:
#     679             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in __getitem__(self, index)
#     229         sample = self.loader(path)
#     230         if self.transform is not None:
# --> 231             sample = self.transform(sample)
#     232         if self.target_transform is not None:
#     233             target = self.target_transform(target)
#
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      93     def __call__(self, img):
#      94         for t in self.transforms:
# ---> 95             img = t(img)
#      96         return img
#      97
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/transforms.py in forward(self, img)
#     359             PIL Image or Tensor: Rescaled image.
#     360         """
# --> 361         return F.resize(img, self.size, self.interpolation, self.max_size, self.antialias)
#     362
#     363     def __repr__(self) -> str:
#
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py in resize(img, size, interpolation, max_size, antialias)
#     488             warnings.warn("Anti-alias option is always applied for PIL Image input. Argument antialias is ignored.")
#     489         pil_interpolation = pil_modes_mapping[interpolation]
# --> 490         return F_pil.resize(img, size=output_size, interpolation=pil_interpolation)
#     491
#     492     return F_t.resize(img, size=output_size, interpolation=interpolation.value, antialias=antialias)
#
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/_functional_pil.py in resize(img, size, interpolation)
#     248         raise TypeError(f"Got inappropriate size arg: {size}")
#     249
# --> 250     return img.resize(tuple(size[::-1]), interpolation)
#     251
#     252
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in resize(self, size, resample, box, reducing_gap)
#    2190                 )
#    2191
# -> 2192         return self._new(self.im.resize(size, resample, box))
#    2193
#    2194     def reduce(self, factor, box=None):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Testing the network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images.

# %% [markdown]
# Testing accuracy on the test set with `dense121` is 84.005%

# %%
model.to(device)
model.eval()
with torch.no_grad():
    total = 0
    total_correct = 0

    for images, labels in testing_loader:

        images, labels = images.to(device), labels.to(
            device)  # Moving to GPU or CPU

        log_ps = model.forward(images)
        ps = torch.exp(log_ps)
        top_ps, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        total_correct += torch.sum(equals.type(torch.FloatTensor)).item()
        total += labels.size(0)

print(f"Accuracy on test images: {total_correct/total*100:.3f}%")
# Out:
# Accuracy on test images: 91.447%

# %% [markdown]
# ## Saving the checkpoint
#
# I might need to completely rebuild the model later, so I'm including all of the information I might need in the checkpoint.

# %%
model.to('cpu')

model.class_to_idx = training_dataset.class_to_idx  # type: ignore

arch = 'densenet121' if model._get_name() == 'DenseNet' else 'alexnet'

checkpoint = {'classifier': model.classifier,
              'arch':       arch,
              'epochs':     epochs,
              'lr': lr,
              'state_dict': model.state_dict(),
              'mapping':    model.class_to_idx
              }

torch.save(checkpoint, f'{arch}-checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint

# %%
def load_checkpoint(checkpoint):
    model_checkpoint = torch.load(checkpoint)

    model_arch = model_checkpoint['arch']
    if model_arch == 'alexnet':
        model = models.alexnet(weights=models.AlexNet_Weights.DEFAULT)
    elif model_arch == 'densenet121':
        model = models.densenet121(weights=models.DenseNet121_Weights.DEFAULT)
    else:
        print('The model architecture is not supported, terminating the program..')
        exit(1)

    model.classifier = model_checkpoint['classifier']
    model.load_state_dict(model_checkpoint['state_dict'])
    model.class_to_idx = model_checkpoint['mapping']
    epochs = model_checkpoint['epochs']
    lr = model_checkpoint['lr']
    return model, epochs, lr

# %%
# Testing the checkpoint method

model, epochs, lr = load_checkpoint('densenet121-checkpoint.pth')
model

# %% [markdown]
# # Inference for classification
#
# Writing a function `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities.
#
# Image processing must be handled first, then the image must be passed through the model to get the probabilities.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    width, height = image.size

    if width < height:
        image = image.resize((256, 256*height//width))
    else:
        image = image.resize((256*width//height, 256))

    width, height = image.size
    reduce = 224
    left = (width - reduce)/2
    top = (height - reduce)/2
    right = left + 224
    bottom = top + 224
    im = image.crop((left, top, right, bottom))

    np_image = np.array(im)/255
    np_image -= np.array([0.485, 0.456, 0.406])
    np_image /= np.array([0.229, 0.224, 0.225])

    np_image = np_image.transpose((2, 0, 1))
    return np_image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()

    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))

    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean

    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)

    ax.imshow(image)

    return ax

# %%
# Checking the image processing

image = Image.open('/content/PlantVillage2/test/Pepper__bell___Bacterial_spot/01940b6d-7dea-4889-a7b8-a35f4e9bba34___NREC_B.Spot 9120.JPG')
image = process_image(image)
imshow(torch.from_numpy(image))

plt.show()

# %% [markdown]
# ## Class Prediction
#
# Now that I have the images in the correct format, the `predict` function is ready to handle making predictions with the model.

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    image = Image.open(image_path)
    image = torch.from_numpy(process_image(image)).type(
        torch.FloatTensor)  # type: ignore

    model.eval()
    with torch.no_grad():
        model.to('cpu')
        # we're using unsqueeze to add a batch dimension so that it wpuld be compatible with the model
        log_ps = model.forward(image.unsqueeze(0))
    ps = torch.exp(log_ps)
    values, indices = ps.topk(topk)

    idx_to_class = {val: key for key, val in model.class_to_idx.items()}
    classes = [idx_to_class[idx] for idx in indices.numpy()[0].tolist()]

    return values, classes

# %% [markdown]
# ## Sanity Checking
#
# Now that we can use a trained model for predictions, I'm checking to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs.

# %%
file_path = '/content/PlantVillage2/test/Pepper__bell___Bacterial_spot/01940b6d-7dea-4889-a7b8-a35f4e9bba34___NREC_B.Spot 9120.JPG'  # an example from test set

img_class = file_path.split('/')[2]

img = Image.open(file_path)
processed_image = process_image(img.copy())

probs, classes = predict(file_path, model, 5)
#classes = [cat_to_name[cls] for cls in classes]

fig, (ax0, ax1) = plt.subplots(ncols=1, nrows=2, figsize=(4, 8))

ax0.imshow(img)
ax0.axis('off')
#ax0.set_title(cat_to_name[img_class])

ax1.barh(classes[::-1], probs.numpy()[0][::-1])

plt.show()
